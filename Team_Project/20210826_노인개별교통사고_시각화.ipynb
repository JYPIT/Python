# %% [markdown]
# ###한글 깨짐 방지

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/4조_팀프로젝트_공유폴더/CSV 파일/노인교통사고개별_전국_차대사람_2018-2020_병수/노인교통사고개별_전국_차대사람_2020_0826_v04_시도추가.csv")

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  ...  피해운전자 연령  피해운전자 상해정도 코드     시도
# 0              0             0               0  ...       65세              4   전라남도
# 1              1             1               1  ...       76세              5  서울특별시
# 2              2             2               2  ...       76세              4  대전광역시
# 3              3             3               3  ...       71세              5  광주광역시
# 4              4             4               4  ...       73세              3  인천광역시
# ...          ...           ...             ...  ...       ...            ...    ...
# 9668        9668          9668            9668  ...       82세              5   경상북도
# 9669        9669          9669            9669  ...       75세              4   경상남도
# 9670        9670          9670            9670  ...       78세              3  광주광역시
# 9671        9671          9671            9671  ...       77세              3   충청북도
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  ...  피해운전자 연령  피해운전자 상해정도 코드     시도
# 0              0             0               0  ...       65세              4   전라남도
# 1              1             1               1  ...       76세              5  서울특별시
# 2              2             2               2  ...       76세              4  대전광역시
# 3              3             3               3  ...       71세              5  광주광역시
# 4              4             4               4  ...       73세              3  인천광역시
# ...          ...           ...             ...  ...       ...            ...    ...
# 9668        9668          9668            9668  ...       82세              5   경상북도
# 9669        9669          9669            9669  ...       75세              4   경상남도
# 9670        9670          9670            9670  ...       78세              3  광주광역시
# 9671        9671          9671            9671  ...       77세              3   충청북도
# ...

# %% [markdown]
# import re
#
# compile_val = re.compile(r'라이언|무지|콘')
# text = ['라이언과 무지는 친구이다.',
#        '라이언과 콘도 친구이다.',
#        '프로도와 네오는 연인이다.',
#        '콘은 크로코다일과 콩알이 조합한 이름이다.',
#        '무지는 토끼옷 입은 단무지이다.',
#        '튜브는 소심한 오리이다.',
#        '어피치는 유전자 변형으로 자웅동주가 된 것을 알고 복숭아 나무에서 탈출하였다.']
#
# for i in text:
#     if compile_val.search(i):
#         print(i)
#     else:
#         print('FALSE')
# ---------------------------------------
# 라이언과 무지는 친구이다.
# 라이언과 콘도 친구이다.
# FALSE
# 콘은 크로코다일과 콩알이 조합한 이름이다.
# 무지는 토끼옷 입은 단무지이다.
# FALSE
# FALSE

# %%
city = ["강원도","경기도","경상남도","경상북도","광주광역시","대구광역시","대전광역시","부산광역시","서울특별시","세종특별자치시","울산광역시","인천광역시","전라남도","전라북도","제주특별자치도","충청남도","충청북도"]

# %%
df[df['시군구'].str.contains("강원도")]
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  ...  피해운전자 연령  피해운전자 상해정도 코드   시도
# 52            52            52              52  ...       78세              3  강원도
# 68            68            68              68  ...       66세              4  강원도
# 147          147           147             147  ...       65세              3  강원도
# 198          198           198             198  ...       85세              4  강원도
# 226          226           226             226  ...       69세              4  강원도
# ...          ...           ...             ...  ...       ...            ...  ...
# 9551        9551          9551            9551  ...       75세              4  강원도
# 9555        9555          9555            9555  ...       79세              2  강원도
# 9604        9604          9604            9604  ...       71세              3  강원도
# 9623        9623          9623            9623  ...       65세              3  강원도
# ...

# %%
df[df['시군구'].str.contains("경기도")]
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  ...  피해운전자 연령  피해운전자 상해정도 코드   시도
# 11            11            11              11  ...       82세              4  경기도
# 22            22            22              22  ...       78세              3  경기도
# 25            25            25              25  ...       74세              3  경기도
# 32            32            32              32  ...       68세              2  경기도
# 44            44            44              44  ...       84세              5  경기도
# ...          ...           ...             ...  ...       ...            ...  ...
# 9634        9634          9634            9634  ...       67세              3  경기도
# 9636        9636          9636            9636  ...       68세              3  경기도
# 9642        9642          9642            9642  ...       70세              3  경기도
# 9645        9645          9645            9645  ...       84세              4  경기도
# ...

# %%
df[df['사고일시'].str.contains("2020년 10월")]
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  ...  피해운전자 연령  피해운전자 상해정도 코드     시도
# 0             0             0               0  ...       65세              4   전라남도
# 1             1             1               1  ...       76세              5  서울특별시
# 2             2             2               2  ...       76세              4  대전광역시
# 3             3             3               3  ...       71세              5  광주광역시
# 4             4             4               4  ...       73세              3  인천광역시
# ..          ...           ...             ...  ...       ...            ...    ...
# 952         952           952             952  ...       71세              4  광주광역시
# 953         953           953             953  ...       83세              4    강원도
# 954         954           954             954  ...       90세              4   전라남도
# 955         955           955             955  ...       50세              3   전라남도
# ...

# %%
df_pivot = df.T
df_pivot
# Out:
#                              0     ...              9672
# Unnamed: 0                      0  ...              9672
# Unnamed: 0.1                    0  ...              9672
# Unnamed: 0.1.1                  0  ...              9672
# 사고번호             2020101000100011  ...  2020090900100509
# 년도                           2020  ...              2020
# 사고일시            2020년 10월 10일 00시  ...   2020년 9월 9일 21시
# 요일                            토요일  ...               수요일
# 시군구                  전라남도 화순군 화순읍  ...  경상남도 창원시 성산구 상남동
# 사고내용코드                          3  ...                 3
# 사망자수                            0  ...                 0
# 중상자수                            1  ...                 1
# 경상자수                            0  ...                 0
# 부상신고자수                          0  ...                 0
# 사고유형코드                          5  ...                 3
# 법규위반코드                          8  ...                 2
# ...

# %%
"""name = input('알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
 
a = df['시군구'].str.contains(name)

df2 = df[a]
print(df2)"""
# Out:
# "name = input('알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')\n \na = df['시군구'].str.contains(name)\n\ndf2 = df[a]\nprint(df2)"

# %%
plt.rcParams['figure.figsize'] = (10,4)
plt.rcParams['figure.dpi'] = 200
#plt.figure(figsize=(10,4),dpi=300)
plt.style.use('ggplot')
#plt.rc('font',family = "NanumBarunGothic")
#plt.title(name+' 지역의 인구 구조')
#df2.T.plot()
#plt.show()

# %% [markdown]
# #노인어린이교통사고_총건수

# %%
df10 = pd.read_excel("/content/drive/MyDrive/4조_팀프로젝트_공유폴더/CSV 파일/노인어린이교통사고_총건수_병수/노인교통사고 2010 -2020_210826_v01_년도별월별정리.xlsx",index_col = 0)

print(df10)
# Out:
#       2010년 1월  2010년 2월  2010년 3월  ...  2020년 10월  2020년 11월  2020년 12월
# 사고건수      1649      1663      1820  ...       3484       3256       2523
# 사망자수       116       107       125  ...        138        110         98
# 부상자수      1712      1758      1911  ...       3746       3539       2688
#
# [3 rows x 132 columns]

# %%
df10.columns
# Out:
# Index(['2010년 1월', '2010년 2월', '2010년 3월', '2010년 4월', '2010년 5월', '2010년 6월',
#        '2010년 7월', '2010년 8월', '2010년 9월', '2010년 10월',
#        ...
#        '2020년 3월', '2020년 4월', '2020년 5월', '2020년 6월', '2020년 7월', '2020년 8월',
#        '2020년 9월', '2020년 10월', '2020년 11월', '2020년 12월'],
#       dtype='object', length=132)

# %%
df10.info
# Out:
# <bound method DataFrame.info of       2010년 1월  2010년 2월  2010년 3월  ...  2020년 10월  2020년 11월  2020년 12월
# 사고건수      1649      1663      1820  ...       3484       3256       2523
# 사망자수       116       107       125  ...        138        110         98
# 부상자수      1712      1758      1911  ...       3746       3539       2688
#
# [3 rows x 132 columns]>

# %%
df10.value_counts
# Out:
# <bound method DataFrame.value_counts of       2010년 1월  2010년 2월  2010년 3월  ...  2020년 10월  2020년 11월  2020년 12월
# 사고건수      1649      1663      1820  ...       3484       3256       2523
# 사망자수       116       107       125  ...        138        110         98
# 부상자수      1712      1758      1911  ...       3746       3539       2688
#
# [3 rows x 132 columns]>

# %%
print(df10.index)
# Out:
# Index(['사고건수', '사망자수', '부상자수'], dtype='object')

# %% [markdown]
# 컬럼 만들기

# %%
df10
# Out:
#       2010년 1월  2010년 2월  2010년 3월  ...  2020년 10월  2020년 11월  2020년 12월
# 사고건수      1649      1663      1820  ...       3484       3256       2523
# 사망자수       116       107       125  ...        138        110         98
# 부상자수      1712      1758      1911  ...       3746       3539       2688
#
# [3 rows x 132 columns]

# %%
df10_t = df10.T

# %%
df10_t
# Out:
#            사고건수  사망자수  부상자수
# 2010년 1월   1649   116  1712
# 2010년 2월   1663   107  1758
# 2010년 3월   1820   125  1911
# 2010년 4월   2022   132  2116
# 2010년 5월   2377   141  2566
# ...         ...   ...   ...
# 2020년 8월   2969   141  3166
# 2020년 9월   3240   137  3483
# 2020년 10월  3484   138  3746
# 2020년 11월  3256   110  3539
# 2020년 12월  2523    98  2688
#
# [132 rows x 3 columns]

# %%
df10_t.shape
# Out:
# (132, 3)

# %%
#series_sum = df10_t.iloc[12:24].sum()
#series_sum

# %% [markdown]
# ###1년씩 나누고 합치기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#df_sum = df10_t.iloc[0:12].sum()
#df_sum

# %%
#type(df_sum)

# %%
df10_t.iloc[120:132]
# Out:
#            사고건수  사망자수  부상자수
# 2020년 1월   2881   130  3082
# 2020년 2월   2456    88  2648
# 2020년 3월   2357    90  2526
# 2020년 4월   2773    85  3040
# 2020년 5월   3173   102  3503
# 2020년 6월   3278   110  3582
# 2020년 7월   2922   113  3144
# 2020년 8월   2969   141  3166
# 2020년 9월   3240   137  3483
# 2020년 10월  3484   138  3746
# 2020년 11월  3256   110  3539
# 2020년 12월  2523    98  2688

# %% [markdown]
# 0:12  2010
# 12:24 2011
# 24:36 2012
# 36:48 2013
# 48:60 2014
# 60:72 2015
# 72:84 2016
# 84:96 2017
# 96:108 2018
# 108:120 2019
# 120:132 2020

# %%
#df_sum = pd.DataFrame(df_sum, columns=['2010']) # series를 DataFrame으로 변환
#df_sum

# %%
#series_sum = df10_t.iloc[120:132].sum()
#series_sum

# %%
#df_sum["2020"] = series_sum
#df_sum

# %%
#df_sum.to_csv("/content/drive/MyDrive/4조_팀프로젝트_공유폴더/CSV 파일/노인어린이교통사고_총건수_병수/2010-2020_연도별_노인교통사고_기록")

# %% [markdown]
# 연도별 노인교통사고 시각화

# %%
df_sum = pd.read_csv("/content/drive/MyDrive/4조_팀프로젝트_공유폴더/CSV 파일/노인어린이교통사고_총건수_병수/2010-2020_연도별_노인교통사고_기록",index_col=0)
df_sum
# Out:
#        2010   2011   2012   2013   2014  ...   2016   2017   2018   2019   2020
# 사고건수  25810  26483  28185  30283  30283  ...  35761  37555  38647  40645  35312
# 사망자수   1752   1724   1864   1833   1833  ...   1732   1767   1682   1523   1342
# 부상자수  27394  27999  29699  32178  32178  ...  38413  40579  41833  44390  38147
#
# [3 rows x 11 columns]

# %%
df_sum.index[0]
# Out:
# '사고건수'

# %%
df_sum.columns
# Out:
# Index(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020'],
#       dtype='object')

# %%
df_sum
# Out:
#        2010   2011   2012   2013   2014  ...   2016   2017   2018   2019   2020
# 사고건수  25810  26483  28185  30283  30283  ...  35761  37555  38647  40645  35312
# 사망자수   1752   1724   1864   1833   1833  ...   1732   1767   1682   1523   1342
# 부상자수  27394  27999  29699  32178  32178  ...  38413  40579  41833  44390  38147
#
# [3 rows x 11 columns]

# %%
df_sum_t = df_sum.T
df_sum_t
# Out:
#        사고건수  사망자수   부상자수
# 2010  25810  1752  27394
# 2011  26483  1724  27999
# 2012  28185  1864  29699
# 2013  30283  1833  32178
# 2014  30283  1833  32178
# 2015  36053  1814  38582
# 2016  35761  1732  38413
# 2017  37555  1767  40579
# 2018  38647  1682  41833
# 2019  40645  1523  44390
# 2020  35312  1342  38147

# %%
import plotly.express as px
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = [10, 6]

fig2 = px.bar(df_sum_t, x= df_sum_t.index,y="사고건수",title="2010-2020 노인 교통사고 사망자 기록")
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7623a95d-3a4e-46a0-9412-90e4c2f87f29" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7623a95d-3a4e-46a0-9412-90e4c2f87f29")) {
#                     Plotly.newPlot(
#                         '7623a95d-3a4e-46a0-9412-90e4c2f87f29',
# ...

# %%
alpha = 0.7


plt.figure(dpi = 200)
#plt.title('Stacked Bar Chart of Sum of Tips by Day & Sex', fontsize=20)

plt.ylabel('사고건수', fontsize=10)
plt.style.use('ggplot')
plt.xlabel('Year', fontsize=10)
plt.bar(df_sum_t.index, df_sum_t["사고건수"], color='blue', alpha=alpha)
plt.xticks(df_sum_t.index, fontsize=10)
plt.title("2010-2020 노인 교통사고 연도별 사고건수")
#plt.legend((p1[0], p2[0]), ('Male', 'Female'), fontsize=15)
plt.show()

# %% [markdown]
# ### 노인 교통사고 총건수 차트 시각화

# %%
import plotly.express as px
import numpy as np

import pandas as pd



import matplotlib.pyplot as plt

import seaborn as sns

plt.rcParams['figure.figsize'] = [10, 6]

fig = px.bar(df10_t, x= df10_t.index,y="사망자수",title="2010-2020 노인 교통사고 사망자 기록")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f1caaf36-657d-49dc-acfc-d8534498f070" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f1caaf36-657d-49dc-acfc-d8534498f070")) {
#                     Plotly.newPlot(
#                         'f1caaf36-657d-49dc-acfc-d8534498f070',
# ...

# %%
"""label = ['Thur', 'Fri', 'Sat', 'Sun']

N = len(tips['day'].unique())

index = np.arange(N)
"""
alpha = 0.5

plt.figure(dpi = 200, figsize=(15,5))

p1 = plt.bar(df10_t.index, df10_t["사망자수"], color='b', alpha=alpha)

p2 = plt.bar(df10_t.index, df10_t["사고건수"], color='r', alpha=alpha,

             bottom=df10_t["사망자수"]) # stacked bar chart

#plt.title('Stacked Bar Chart of Sum of Tips by Day & Sex', fontsize=20)

plt.ylabel('사망자수', fontsize=10)

plt.xlabel('Year/Month', fontsize=10)

plt.xticks(df10_t.index, fontsize=5,rotation="45")

#plt.legend((p1[0], p2[0]), ('Male', 'Female'), fontsize=15)

plt.show()

# %% [markdown]
# #2018-2020 지역별 연간 노인 인구수

# %%
senior_num = pd.read_csv("/content/drive/MyDrive/4조_팀프로젝트_공유폴더/CSV 파일/지역별_노인_인구현황_박준엽/2018-2020 연간 노인 인구수.csv",index_col=0)
senior_num
# Out:
#                        2018년_계_총인구수  ...  2020년_계_100세 이상
# 행정구역                                 ...
# 서울특별시  (1100000000)         9765623  ...             6792
# 부산광역시  (2600000000)         3441453  ...             1887
# 대구광역시  (2700000000)         2461769  ...              733
# 인천광역시  (2800000000)         2954642  ...              969
# 광주광역시  (2900000000)         1459336  ...              424
# 대전광역시  (3000000000)         1489936  ...              371
# 울산광역시  (3100000000)         1155623  ...              175
# 세종특별자치시  (3600000000)        314126  ...               50
# 경기도  (4100000000)          13077153  ...             4315
# 강원도  (4200000000)           1543052  ...              864
# 충청북도  (4300000000)          1599252  ...              569
# 충청남도  (4400000000)          2126282  ...              921
# 전라북도  (4500000000)          1836832  ...              856
# 전라남도  (4600000000)          1882970  ...              870
# ...

# %%
senior_num.columns
# Out:
# Index(['2018년_계_총인구수', '2018년_계_연령구간인구수', '2018년_계_65~69세', '2018년_계_70~74세',
#        '2018년_계_75~79세', '2018년_계_80~84세', '2018년_계_85~89세', '2018년_계_90~94세',
#        '2018년_계_95~99세', '2018년_계_100세 이상', '2019년_계_총인구수', '2019년_계_연령구간인구수',
#        '2019년_계_65~69세', '2019년_계_70~74세', '2019년_계_75~79세', '2019년_계_80~84세',
#        '2019년_계_85~89세', '2019년_계_90~94세', '2019년_계_95~99세', '2019년_계_100세 이상',
#        '2020년_계_총인구수', '2020년_계_연령구간인구수', '2020년_계_65~69세', '2020년_계_70~74세',
#        '2020년_계_75~79세', '2020년_계_80~84세', '2020년_계_85~89세', '2020년_계_90~94세',
#        '2020년_계_95~99세', '2020년_계_100세 이상'],
#       dtype='object')

# %%
senior_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 서울특별시  (1100000000) to 제주특별자치도  (5000000000)
# Data columns (total 30 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   2018년_계_총인구수     17 non-null     int64
#  1   2018년_계_연령구간인구수  17 non-null     int64
#  2   2018년_계_65~69세   17 non-null     int64
#  3   2018년_계_70~74세   17 non-null     int64
#  4   2018년_계_75~79세   17 non-null     int64
#  5   2018년_계_80~84세   17 non-null     int64
#  6   2018년_계_85~89세   17 non-null     int64
#  7   2018년_계_90~94세   17 non-null     int64
#  8   2018년_계_95~99세   17 non-null     int64
#  9   2018년_계_100세 이상  17 non-null     int64
#  10  2019년_계_총인구수     17 non-null     int64
#  11  2019년_계_연령구간인구수  17 non-null     int64
#  12  2019년_계_65~69세   17 non-null     int64
#  13  2019년_계_70~74세   17 non-null     int64
#  14  2019년_계_75~79세   17 non-null     int64
#  15  2019년_계_80~84세   17 non-null     int64
# ...

# %%
senior_num.shape
# Out:
# (17, 30)

# %%
senior_num.iloc[:10]
# Out:
#                        2018년_계_총인구수  ...  2020년_계_100세 이상
# 행정구역                                 ...
# 서울특별시  (1100000000)         9765623  ...             6792
# 부산광역시  (2600000000)         3441453  ...             1887
# 대구광역시  (2700000000)         2461769  ...              733
# 인천광역시  (2800000000)         2954642  ...              969
# 광주광역시  (2900000000)         1459336  ...              424
# 대전광역시  (3000000000)         1489936  ...              371
# 울산광역시  (3100000000)         1155623  ...              175
# 세종특별자치시  (3600000000)        314126  ...               50
# 경기도  (4100000000)          13077153  ...             4315
# 강원도  (4200000000)           1543052  ...              864
#
# [10 rows x 30 columns]

# %%
#df_sum = pd.DataFrame(df_sum, columns=['2010']) # series를 DataFrame으로 변환
#df_sum

# %% [markdown]
# #어린이보호구역 vs 노인보호구역

# %% [markdown]
# ###노인보호구역

# %%
senior_loc = pd.read_csv("/content/drive/MyDrive/4조_팀프로젝트_공유폴더/CSV 파일/노인어린이보호구역_준엽/전국노인보호구역표준데이터_수정.csv",encoding="cp949",index_col=0)
senior_loc
# Out:
#                시도명 시군구명  시군구코드  ...     데이터기준일자   제공기관코드      제공기관명
# 대상시설명                           ...
# 금일읍경로조합복지회관   전라남도  완도군  49900  ...  2020-09-02  4990000   전라남도 완도군
# 오사2리 생동노인회관   충청남도  서산시  44210  ...  2020-06-26  4530000   충청남도 서산시
# 거성3리 경로당      충청남도  서산시  44210  ...  2020-06-26  4530000   충청남도 서산시
# 읍내3리 경로당      충청남도  서산시  44210  ...  2020-06-26  4530000   충청남도 서산시
# 신송1리 경로회관     충청남도  서산시  44210  ...  2020-06-26  4530000   충청남도 서산시
# ...            ...  ...    ...  ...         ...      ...        ...
# 중구노인복지관      부산광역시   중구  26110  ...  2021-04-28  3250000   부산광역시 중구
# 중구노인복지회관분관   부산광역시   중구  26110  ...  2021-04-28  3250000   부산광역시 중구
# 백산강화실버홈      인천광역시  강화군  35700  ...  2021-04-26  3570000  인천광역시 강화군
# 호세요양원        인천광역시  강화군  35700  ...  2021-04-26  3570000  인천광역시 강화군
# 강화노인복지관      인천광역시  강화군  35700  ...  2021-04-26  3570000  인천광역시 강화군
#
# [2258 rows x 17 columns]

# %%
senior_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2258 entries, 금일읍경로조합복지회관 to 강화노인복지관
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시도명       2258 non-null   object
#  1   시군구명      2258 non-null   object
#  2   시군구코드     2258 non-null   int64
#  3   소재지도로명주소  2258 non-null   object
#  4   소재지지번주소   1448 non-null   object
#  5   위도        2258 non-null   float64
#  6   경도        2258 non-null   float64
#  7   제한속도      2258 non-null   int64
#  8   관리기관명     2258 non-null   object
#  9   관리기관전화번호  2258 non-null   object
#  10  관할경찰서명    2258 non-null   object
#  11  CCTV설치여부  2258 non-null   object
#  12  CCTV설치대수  1142 non-null   float64
#  13  보호구역도로폭   1362 non-null   object
#  14  데이터기준일자   2258 non-null   object
#  15  제공기관코드    2258 non-null   int64
#  16  제공기관명     2258 non-null   object
# dtypes: float64(3), int64(3), object(11)
# memory usage: 317.5+ KB

# %%
senior_loc[senior_loc['소재지도로명주소'].str.contains("충청남도")]
# Out:
#               시도명 시군구명  시군구코드  ...     데이터기준일자   제공기관코드     제공기관명
# 대상시설명                          ...
# 오사2리 생동노인회관  충청남도  서산시  44210  ...  2020-06-26  4530000  충청남도 서산시
# 거성3리 경로당     충청남도  서산시  44210  ...  2020-06-26  4530000  충청남도 서산시
# 읍내3리 경로당     충청남도  서산시  44210  ...  2020-06-26  4530000  충청남도 서산시
# 신송1리 경로회관    충청남도  서산시  44210  ...  2020-06-26  4530000  충청남도 서산시
# 갈산3통 경로당     충청남도  서산시  44210  ...  2020-06-26  4530000  충청남도 서산시
# ...           ...  ...    ...  ...         ...      ...       ...
# 명암리 노인회관     충청남도  금산군  44710  ...  2021-01-11  6440000      충청남도
# 원구석 경로당      충청남도  금산군  44710  ...  2021-01-11  6440000      충청남도
# 부암2리 경로당     충청남도  금산군  44710  ...  2021-01-11  6440000      충청남도
# 의총2리 경로당     충청남도  금산군  44710  ...  2021-01-11  6440000      충청남도
# 신정1리 경로당     충청남도  금산군  44710  ...  2021-01-11  6440000      충청남도
#
# [985 rows x 17 columns]

# %%
senior_loc
# Out:
#                시도명 시군구명  시군구코드  ...     데이터기준일자   제공기관코드      제공기관명
# 대상시설명                           ...
# 금일읍경로조합복지회관   전라남도  완도군  49900  ...  2020-09-02  4990000   전라남도 완도군
# 오사2리 생동노인회관   충청남도  서산시  44210  ...  2020-06-26  4530000   충청남도 서산시
# 거성3리 경로당      충청남도  서산시  44210  ...  2020-06-26  4530000   충청남도 서산시
# 읍내3리 경로당      충청남도  서산시  44210  ...  2020-06-26  4530000   충청남도 서산시
# 신송1리 경로회관     충청남도  서산시  44210  ...  2020-06-26  4530000   충청남도 서산시
# ...            ...  ...    ...  ...         ...      ...        ...
# 중구노인복지관      부산광역시   중구  26110  ...  2021-04-28  3250000   부산광역시 중구
# 중구노인복지회관분관   부산광역시   중구  26110  ...  2021-04-28  3250000   부산광역시 중구
# 백산강화실버홈      인천광역시  강화군  35700  ...  2021-04-26  3570000  인천광역시 강화군
# 호세요양원        인천광역시  강화군  35700  ...  2021-04-26  3570000  인천광역시 강화군
# 강화노인복지관      인천광역시  강화군  35700  ...  2021-04-26  3570000  인천광역시 강화군
#
# [2258 rows x 17 columns]

# %%
senior_size = senior_loc.groupby('시도명',as_index=False).size().sort_values(by=['size'])
senior_size
# Out:
#         시도명  size
# 9   세종특별자치시     5
# 5     대구광역시    11
# 13     전라북도    23
# 4     광주광역시    26
# 0       강원도    34
# 12     전라남도    38
# 7     부산광역시    42
# 11    인천광역시    51
# 2      경상남도    65
# 10    울산광역시    69
# 6     대전광역시    85
# 14  제주특별자치도    88
# 8     서울특별시   136
# 3      경상북도   144
# 16     충청북도   176
# 1       경기도   280
# 15     충청남도   985

# %%
alpha = 0.7

plt.figure(dpi = 200, figsize=(20,4))

plt.bar(senior_size['시도명'], senior_size['size'], color='b', alpha=alpha) # stacked bar chart

plt.title('2021년 노인보호구역수', fontsize=20)

plt.ylabel('노인보호구역수', fontsize=10)

#plt.xlabel('지역명', fontsize=15)

#plt.xticks(df10_t.index, fontsize=5,rotation="45")

#plt.legend((p1[0], p2[0]), ('Male', 'Female'), fontsize=15)

plt.show()

# %% [markdown]
# ###어린이 보호구역수

# %%
child_loc = pd.read_csv("/content/drive/MyDrive/4조_팀프로젝트_공유폴더/CSV 파일/노인어린이보호구역_준엽/전국어린이보호구역표준데이터_수정_V02_지역명수정.csv",encoding="cp949",index_col=0)
child_loc
# Out:
#            대상시설명                            소재지도로명주소  ... 보호구역도로폭     데이터기준일자
# 시설종류                                                  ...
# 초등학교      오덕초등학교                  강원도 철원군 동송읍 오덕로159  ...       6  2020-08-26
# 초등학교      문혜초등학교                 강원도 철원군 갈말읍 태봉로1556  ...       6  2020-08-26
# 어린이집     로이스어린이집               대구광역시 달서구 진천로3길 85-11  ...       6  2021-03-15
# 어린이집      예원어린이집              대구광역시 달서구 월곡로47안길 33-7  ...       6  2021-03-15
# 어린이집      해뜰어린이집              대구광역시 달서구 월곡로47안길 33-4  ...       6  2021-03-15
# ...          ...                                 ...  ...     ...         ...
# 어린이집    정인아트어린이집               인천광역시 계양구 계산천서로24번길12  ...     NaN  2021-06-07
# 어린이집      하늘어린이집              인천광역시 계양구 경명대로1078번길14  ...     NaN  2021-06-07
# 어린이집  태양창의아트어린이집             인천광역시 계양구 주부토로529번길13-1  ...     NaN  2021-06-07
# 어린이집   귤현꿈나무어린이집                    인천광역시 계양구 귤현길 12  ...     NaN  2021-06-07
# ...

# %%
child_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17576 entries, 초등학교 to 유치원
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   대상시설명     17576 non-null  object
#  1   소재지도로명주소  17576 non-null  object
#  2   소재지지번주소   14203 non-null  object
#  3   위도        17576 non-null  float64
#  4   경도        17576 non-null  float64
#  5   관리기관명     17576 non-null  object
#  6   관할경찰서명    17576 non-null  object
#  7   CCTV설치여부  17576 non-null  object
#  8   CCTV설치대수  12857 non-null  float64
#  9   보호구역도로폭   12436 non-null  object
#  10  데이터기준일자   17576 non-null  object
# dtypes: float64(3), object(8)
# memory usage: 1.6+ MB

# %%
child_loc[child_loc['소재지도로명주소'].str.contains("서울특별시")]
# Out:
#             대상시설명               소재지도로명주소  ... 보호구역도로폭     데이터기준일자
# 시설종류                                      ...
# 초등학교  청파초교(병설유치원)     서울특별시 용산구 효창원로 228  ...    4~12  2020-02-18
# 어린이집    강동복지관어린이집    서울특별시 강동구 진황도로23길 7  ...       6  2020-09-11
# 어린이집    올리브나무어린이집  서울특별시 강동구 양재대로134길 41  ...       6  2020-09-11
# 어린이집    자이젠킨더어린이집  서울특별시 강동구 천호대로199길 25  ...       5  2020-09-11
# 어린이집    강동무지개어린이집  서울특별시 강동구 양재대로125길 30  ...       6  2020-09-11
# ...           ...                    ...  ...     ...         ...
# 유치원       방배병설유치원  서울특별시 서초구 방배중앙로13길 26  ...       1  2020-07-01
# 유치원        새성민유치원      서울특별시 서초구 효령로 110  ...       1  2020-07-01
# 유치원         새순유치원   서울특별시 서초구 서초대로15길 57  ...       1  2020-07-01
# 유치원       서래병설유치원      서울특별시 서초구 방배로 260  ...       1  2020-07-01
# 유치원      서울청계숲유치원   서울특별시 서초구 청계산로11길 14  ...       1  2020-07-01
#
# [1646 rows x 11 columns]

# %% [markdown]
# ###시도명 컬럼 추가

# %%
#child_loc['시도명'] = child_loc['소재지도로명주소'].str.split().str[0]
#child_loc
# Out:
#            대상시설명                            소재지도로명주소  ...     데이터기준일자    시도명
# 시설종류                                                  ...
# 초등학교      오덕초등학교                  강원도 철원군 동송읍 오덕로159  ...  2020-08-26    강원도
# 초등학교      문혜초등학교                 강원도 철원군 갈말읍 태봉로1556  ...  2020-08-26    강원도
# 어린이집     로이스어린이집               대구광역시 달서구 진천로3길 85-11  ...  2021-03-15  대구광역시
# 어린이집      예원어린이집              대구광역시 달서구 월곡로47안길 33-7  ...  2021-03-15  대구광역시
# 어린이집      해뜰어린이집              대구광역시 달서구 월곡로47안길 33-4  ...  2021-03-15  대구광역시
# ...          ...                                 ...  ...         ...    ...
# 어린이집    정인아트어린이집               인천광역시 계양구 계산천서로24번길12  ...  2021-06-07  인천광역시
# 어린이집      하늘어린이집              인천광역시 계양구 경명대로1078번길14  ...  2021-06-07  인천광역시
# 어린이집  태양창의아트어린이집             인천광역시 계양구 주부토로529번길13-1  ...  2021-06-07  인천광역시
# 어린이집   귤현꿈나무어린이집                    인천광역시 계양구 귤현길 12  ...  2021-06-07  인천광역시
# ...

# %% [markdown]
# ###데이터프레임 컬럼 순서 변경

# %%
# 데이터프레임 컬럼 순서 변경
child_loc.columns
# Out:
# Index(['대상시설명', '소재지도로명주소', '소재지지번주소', '위도', '경도', '관리기관명', '관할경찰서명',
#        'CCTV설치여부', 'CCTV설치대수', '보호구역도로폭', '데이터기준일자', '시도명'],
#       dtype='object')

# %%
#child_loc = child_loc[['대상시설명','시도명', '소재지도로명주소', '소재지지번주소', '위도', '경도', '관리기관명', '관할경찰서명','CCTV설치여부', 'CCTV설치대수', '보호구역도로폭', '데이터기준일자']]

# %%
child_loc['시도명'].unique()
# Out:
# array(['강원도', '대구광역시', '제주특별자치도', '전라북도', '인천광역시', '전라남도', '경기도', '부산광역시',
#        '충청남도', '경상북도', '경상남도', '충청북도', '서울특별시', '대전광역시', '울산광역시', '광주광역시',
#        '세종특별자치시'], dtype=object)

# %%
#child_loc.to_csv("/content/drive/MyDrive/4조_팀프로젝트_공유폴더/CSV 파일/노인어린이보호구역_준엽/전국어린이보호구역표준데이터_수정_V03_컬럼순서변경.csv")

# %%
child_loc = pd.read_csv("/content/drive/MyDrive/4조_팀프로젝트_공유폴더/CSV 파일/노인어린이보호구역_준엽/전국어린이보호구역표준데이터_수정_V03_컬럼순서변경.csv",index_col=0)
child_loc
# Out:
#            대상시설명    시도명  ... 보호구역도로폭     데이터기준일자
# 시설종류                     ...
# 초등학교      오덕초등학교    강원도  ...       6  2020-08-26
# 초등학교      문혜초등학교    강원도  ...       6  2020-08-26
# 어린이집     로이스어린이집  대구광역시  ...       6  2021-03-15
# 어린이집      예원어린이집  대구광역시  ...       6  2021-03-15
# 어린이집      해뜰어린이집  대구광역시  ...       6  2021-03-15
# ...          ...    ...  ...     ...         ...
# 어린이집    정인아트어린이집  인천광역시  ...     NaN  2021-06-07
# 어린이집      하늘어린이집  인천광역시  ...     NaN  2021-06-07
# 어린이집  태양창의아트어린이집  인천광역시  ...     NaN  2021-06-07
# 어린이집   귤현꿈나무어린이집  인천광역시  ...     NaN  2021-06-07
# 유치원       예지슬유치원    경기도  ...    3~40  2021-07-01
#
# [17576 rows x 12 columns]

# %% [markdown]
# ###지역별 어린이 보호구역으로 변경

# %%
child_size = child_loc.groupby('시도명',as_index=False).size().sort_values(by=['size'])
child_size
# Out:
#         시도명  size
# 9   세종특별자치시    65
# 14  제주특별자치도   240
# 4     광주광역시   600
# 0       강원도   612
# 11    인천광역시   669
# 10    울산광역시   694
# 12     전라남도   803
# 7     부산광역시   882
# 13     전라북도  1010
# 3      경상북도  1027
# 6     대전광역시  1074
# 16     충청북도  1118
# 15     충청남도  1281
# 2      경상남도  1413
# 5     대구광역시  1575
# 8     서울특별시  1646
# 1       경기도  2867

# %%
alpha = 0.7

plt.figure(dpi = 200, figsize=(20,4))

plt.bar(child_size['시도명'], child_size['size'], color='b', alpha=alpha) # stacked bar chart

plt.title('2021년 어린이보호구역수', fontsize=20)

plt.ylabel('어린이보호구역수', fontsize=10)

#plt.xlabel('지역명', fontsize=15)

#plt.xticks(df10_t.index, fontsize=5,rotation="45")

#plt.legend((p1[0], p2[0]), ('Male', 'Female'), fontsize=15)

plt.show()

# %% [markdown]
# #2010-2020 어린이 교통사고 감소하는 추세 그래프로 그리기

# %%
child_acc = pd.read_csv("/content/drive/MyDrive/4조_팀프로젝트_공유폴더/CSV 파일/노인어린이교통사고_총건수_병수/어린이교통사고_2010 -2020_210827_v01_월별정리.csv",index_col=0)
child_acc
# Out:
#       2010년 1월  2010년 2월  2010년 3월  ...  2020년 10월  2020년 11월  2020년 12월
# 사고건수       842       896      1006  ...        829        695        445
# 사망자수        11        14         8  ...          3          2          1
# 부상자수      1124      1120      1200  ...       1081        862        559
#
# [3 rows x 132 columns]

# %%
child_acc_t.iloc[:12].sum()
# Out:
# 사고건수    14095
# 사망자수      126
# 부상자수    17178
# dtype: int64

# %%
child_acc_t = child_acc.T

# %%
alpha = 0.7


plt.figure(dpi = 200)
#plt.title('Stacked Bar Chart of Sum of Tips by Day & Sex', fontsize=20)

plt.ylabel('사고건수', fontsize=10)
plt.style.use('ggplot')
plt.xlabel('Year', fontsize=10)
plt.bar(child_acc_t.index, child_acc_t['사고건수'], color='blue', alpha=alpha)
#plt.xticks(child, fontsize=10)
plt.title("2010-2020 노인 교통사고 연도별 사고건수")
#plt.legend((p1[0], p2[0]), ('Male', 'Female'), fontsize=15)
plt.show()
